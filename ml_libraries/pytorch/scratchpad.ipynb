# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
x = torch.rand(4,1)
x = (x * 100).to(torch.int16)  # scale + convert to int16
y = x * 2

print(x)
print(y)
# Out:
# tensor([[99],
#         [15],
#         [ 9],
#         [ 5]], dtype=torch.int16)
# tensor([[198],
#         [ 30],
#         [ 18],
#         [ 10]], dtype=torch.int16)

# %%
w1 = torch.rand(4,1, requires_grad=True)
b1 = torch.rand(1, requires_grad=True)
